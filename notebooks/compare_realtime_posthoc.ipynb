# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
predictions = np.load('../processed_data/predict_sim.npy')
onset_times = np.load('../processed_data/onset_times.npy')

# %%
stim_on = 2
behavior_times = np.where(predictions==stim_on)[0]/10
behavior_times
# Out:
# array([  1.2,   1.3,   2.8,   3. ,   3.1,   3.2,   3.3,   3.4,   5.2,
#          5.5,   5.6,  13.6,  13.8,  14.7,  14.9,  15. ,  15.1,  15.2,
#         15.3,  15.4,  16.2,  18.9,  19. ,  25.4,  25.5,  32. ,  34.1,
#         34.2,  41. ,  41.1,  41.4,  41.5,  41.7,  41.8,  41.9,  42. ,
#         42.1,  42.4,  42.7,  42.8,  42.9,  43. ,  43.1,  44.1,  44.2,
#         44.4,  44.5,  45. ,  45.1,  45.6,  45.7,  45.8,  45.9,  48.5,
#         75.5,  76.9,  80.4,  80.5,  80.6,  80.7,  80.8,  80.9,  81. ,
#         81.1,  84.1, 103.9, 104. , 104.1, 104.2, 104.3, 104.4, 107.8,
#        107.9, 108. , 108.5, 109.1, 109.3, 109.4, 109.5, 110.7, 111.2,
#        111.3, 111.4, 113.3, 113.4, 113.5, 113.6, 113.7, 113.8, 113.9,
#        117.6, 117.7, 117.8, 117.9, 118. , 120.2, 120.3, 120.4, 120.5,
#        123.7, 127.6, 127.8, 130.3, 130.4, 136.5, 136.6, 136.7, 144.1,
#        144.3, 144.4, 144.5, 149.1, 149.7, 149.8, 149.9, 150.5, 154.4,
# ...

# %%
onset_times
# Out:
# array([[  5.5063324 ],
#        [ 10.37359571],
#        [ 11.07834077],
#        [ 24.54595494],
#        [ 25.80758095],
#        [ 26.70770502],
#        [ 29.58102131],
#        [ 34.45055914],
#        [ 36.77969241],
#        [ 43.61634421],
#        [ 46.12221956],
#        [ 58.01275253],
#        [ 61.77102995],
#        [ 68.98609185],
#        [ 69.6915009 ],
#        [ 74.25853992],
#        [ 74.79936886],
#        [ 75.31132936],
#        [ 76.55790043],
#        [ 77.099159  ],
#        [ 79.80464816],
#        [ 80.88646412],
#        [ 81.24685717],
#        [ 82.47924876],
#        [ 87.51222491],
#        [ 90.75294256],
#        [128.96767306],
#        [132.91482377],
#        [134.35600352],
#        [135.07510495],
#        [138.66151524],
#        [139.02135849],
#        [141.90899181],
#        [144.79158902],
#        [187.32403994],
#        [194.64782023],
#        [196.97985721],
#        [197.50335097],
#        [200.92834473],
#        [204.53650284],
# ...
