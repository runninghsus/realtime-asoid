# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
predictions = np.load('../processed_data/predict_sim2.npy')
onset_times = np.load('../processed_data/onset_times2.npy')

# %%
stim_on = 2
behavior_times = np.where(predictions==stim_on)[0]/10
behavior_times
# Out:
# array([  1.4,   4.2,   4.3,   4.6,   4.8,   6.9,   8.4,   8.5,   8.6,
#          8.7,   8.8,   8.9,   9. ,   9.1,  10.8,  10.9,  11.2,  18.9,
#         19.4,  20.3,  20.5,  20.6,  20.7,  20.8,  20.9,  21. ,  24.3,
#         24.5,  24.6,  24.7,  31. ,  31.1,  37.6,  37.7,  39.8,  43.8,
#         43.9,  46.7,  46.8,  46.9,  47.1,  47.3,  47.4,  47.5,  47.6,
#         47.7,  48. ,  48.1,  48.3,  48.4,  48.5,  48.6,  48.7,  48.8,
#         49.8,  50. ,  50.2,  50.5,  50.6,  50.7,  51.2,  51.3,  51.4,
#         51.5,  56. ,  77.6,  79.3,  79.5,  79.8,  80.3,  80.5,  82.5,
#         82.6,  84.1,  86.1,  86.2,  86.4,  86.5,  86.6,  86.7,  86.8,
#         89.8, 109.5, 109.6, 109.7, 109.8, 109.9, 110. , 113.4, 113.5,
#        113.6, 114.1, 114.9, 115. , 115.1, 116.8, 116.9, 117. , 117.6,
#        118.9, 119. , 119.1, 119.2, 119.3, 119.4, 119.5, 123.2, 123.3,
#        123.4, 123.5, 123.6, 125. , 125.9, 126. , 126.1, 126.2, 129.3,
# ...

# %%
onset_times
# Out:
# array([[  7.10892129],
#        [  8.92413712],
#        [ 10.75962305],
#        [ 13.93112397],
#        [ 16.90207863],
#        [ 17.80288529],
#        [ 18.35635257],
#        [ 18.71674418],
#        [ 19.25791717],
#        [ 32.8086791 ],
#        [ 35.21708417],
#        [ 37.87174916],
#        [ 42.92725253],
#        [ 44.38546968],
#        [ 45.25557089],
#        [ 51.99293637],
#        [ 54.47997499],
#        [ 66.57653761],
#        [ 70.48385906],
#        [ 77.49090338],
#        [ 78.40317225],
#        [ 82.84502506],
#        [ 83.38559079],
#        [ 83.92389202],
#        [ 85.3052845 ],
#        [ 85.62160587],
#        [ 88.50295568],
#        [ 89.97225642],
#        [ 91.06802464],
#        [ 99.54387665],
#        [137.85655355],
#        [142.10198808],
#        [144.03735161],
#        [147.54712176],
#        [150.90650678],
#        [153.94446063],
#        [196.39519143],
#        [202.89093137],
#        [203.42920971],
#        [205.6214304 ],
# ...
