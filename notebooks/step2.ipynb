# %%
import matplotlib.pyplot as plt
import pandas as pd
import sys
sys.path.append("../")
from utils.preprocessing import *
from scipy import stats

# %%
pose = np.load('../processed_data/pose_video_2.npy', allow_pickle=True)

# %%
features, scaled_features = feature_extraction([pose], 1, framerate=30)

# %%
print(f'features {features.shape} dimension summarized pose with {pose.shape} dimension')
# Out:
# features (82045, 36) dimension summarized pose with (246136, 12) dimension

# %% [markdown]
# ### save processed features

# %%
np.save('../processed_data/features_video_2.npy', [features, scaled_features])

# %%
# plot scaled features
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
# skippign every 0.5s for better understanding
# ax.imshow(scaled_features.T[:, ::10], vmin=-2, vmax=2, cmap='RdBu_r')
# ax.imshow(scaled_features.T[:, ::50], vmin=-2, vmax=2, cmap='RdBu_r')
ax.imshow(scaled_features.T[:, :500], vmin=-2, vmax=2, cmap='RdBu_r')
plt.show()
